# %%
import os
import warnings

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
from matplotlib.axes._axes import _log as matplotlib_axes_logger
import seaborn as sns
import pandas as pd
import earthpy as et
import datetime
import matplotlib.ticker

# Handle data time conversion between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Dealing with error thrown by one of the plots
matplotlib_axes_logger.setLevel('ERROR')
warnings.filterwarnings('ignore')

# Adjust font size and style of all plots in notebook with seaborn
sns.set(font_scale=1.5, style="whitegrid")

# %%
path_to_working_directory = os.path.join(et.io.HOME, "earth-analytics", "LCRWS")

if os.path.exists(path_to_working_directory):
    print("Path exists, set as working directory")
    os.chdir(os.path.join(et.io.HOME, "earth-analytics", "LCRWS"))
else:
    print("Path does not exist, creating directories")
    os.mkdir(path_to_working_directory)
    os.chdir(os.path.join(et.io.HOME, "earth-analytics", "LCRWS"))
# Out:
# Path exists, set as working directory

# %%
data_path = os.path.join(path_to_working_directory,"data","r20-95-06.csv")
cl_80 = os.path.join(path_to_working_directory,'data', "CL-80C.csv")

# %%
cl_80_df = pd.read_csv(cl_80,
                       parse_dates=['date'],
                       index_col=['date'])
cl_80_df['head'].min()
cl_80_df
# Out:
#                         well      type      head
# date
# 2015-07-01 00:00:00   CL-80C  computed  1119.771
# 2015-07-01 02:24:00   CL-80C  computed  1119.771
# 2015-07-01 04:48:00   CL-80C  computed  1119.771
# 2015-07-01 07:12:00   CL-80C  computed  1119.771
# 2015-07-01 09:36:00   CL-80C  computed  1119.771
# ...                      ...       ...       ...
# 2015-07-27 00:00:00  Airport  observed  1119.850
# 2015-07-28 00:00:00  Airport  observed  1119.840
# 2015-07-29 00:00:00  Airport  observed  1119.830
# 2015-07-30 00:00:00  Airport  observed  1119.830
# 2015-07-31 00:00:00  Airport  observed  1119.820
#
# [2331 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(20,10))
for j, p in cl_80_df[cl_80_df["well"] == "CL-80C"].groupby('type'):
    p.groupby('type').plot(y='head',
                           label=j,
                           ax=ax)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
ax.set(title="CL-80C Computed and Observed Values",
       xlabel="Date",
       ylabel="Hydraulic Head",
       ylim=(1116,1122))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
for j, p in cl_80_df[cl_80_df["well"] == "R20-2015-08"].groupby('type'):
    p.groupby('type').plot(y='head',
                           label=j,
                           ax=ax)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
ax.set(title="R20-2015-08 Computed and Observed Values",
       xlabel="Date",
       ylabel="Hydraulic Head",
       ylim=(1116,1122))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
for j, p in cl_80_df[cl_80_df["well"] == "R20-2015-07"].groupby('type'):
    p.groupby('type').plot(y='head',
                           label=j,
                           ax=ax)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
ax.set(title="R20-2015-07 Computed and Observed Values",
       xlabel="Date",
       ylabel="Hydraulic Head",
       ylim=(1116,1122))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
for j, p in cl_80_df[cl_80_df["well"] == "R20-2015-09"].groupby('type'):
    p.groupby('type').plot(y='head',
                           label=j,
                           ax=ax)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
ax.set(title="R20-2015-09 Computed and Observed Values",
       xlabel="Date",
       ylabel="Hydraulic Head",
       ylim=(1116,1122))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
for j, p in cl_80_df[cl_80_df["well"] == "R20-2015-10"].groupby('type'):
    p.groupby('type').plot(y='head',
                           label=j,
                           ax=ax)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
ax.set(title="R20-2015-10 Computed and Observed Values",
       xlabel="Date",
       ylabel="Hydraulic Head",
       ylim=(1116,1122))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
for j, p in cl_80_df[cl_80_df["well"] == "R20-2015-06"].groupby('type'):
    p.groupby('type').plot(y='head',
                           label=j,
                           ax=ax)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
ax.set(title="R20-2015-06 Computed and Observed Values",
       xlabel="Date",
       ylabel="Hydraulic Head",
       ylim=(1116,1122))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,5))
for j, p in cl_80_df[cl_80_df["well"] == "Airport"].groupby('type'):
    p.groupby('type').plot(y='head',
                           label=j,
                           ax=ax)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
ax.set(title="Airport Computed and Observed Values",
       xlabel="Date",
       ylabel="Hydraulic Head",
       ylim=(1116,1122))
plt.show()

# %%
df = pd.read_csv(data_path,
                 parse_dates=['date'],
                 index_col=['date'])

# %%
fig, ax = plt.subplots(figsize=(20,10))

for i, k in df.groupby('type'):
    k.groupby('type').plot(
                           y='head',
                           label=i,
                           ax=ax)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
ax.set(title="R20-95-06 Computed and Observed Values",
       xlabel="Date",
       ylabel="Hydraulic Head",
       ylim=(1116,1122))
plt.show()
